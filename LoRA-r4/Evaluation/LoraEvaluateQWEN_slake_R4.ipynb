# %%
# !pip install -U datasets
# !pip install fsspec==2023.9.2
# !pip install datasets
# !pip install peft
# !pip install -U bitsandbytes

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# Token is valid (permission: fineGrained).
# The token `1` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `1`

# %%
import torch
from transformers import AutoModel
from peft import PeftModel
import torch
from transformers import BitsAndBytesConfig
from transformers import AutoProcessor, BitsAndBytesConfig, AutoModelForImageTextToText,AutoModelForVision2Seq
from peft import LoraConfig
base_model_name = "Qwen/Qwen2-VL-7B-Instruct"

adapters_name = "Dtarget/R49Jqwenloraslakee"

bnb_config = {
    "load_in_4bit": True,
    "bnb_4bit_quant_type": "nf4",
    "bnb_4bit_compute_dtype": torch.float16
}

# Load the base model with QLoRA for memory efficiency
modelF = AutoModelForVision2Seq.from_pretrained(
    base_model_name,
    torch_dtype=torch.float16,
    quantization_config=bnb_config  # QLoRA for memory efficiency
)


modelF = PeftModel.from_pretrained(modelF, adapters_name)
modelF = modelF.merge_and_unload()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# adapter_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:348: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(

# %%
processor = AutoProcessor.from_pretrained(
    "Qwen/Qwen2-VL-7B-Instruct",
    do_image_splitting=False
)
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.

# %%
from datasets import load_dataset

# %%
dataset = load_dataset("mdwiratathya/SLAKE-vqa-english")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# train-00000-of-00002.parquet:   0%|          | 0.00/31.1M [00:00<?, ?B/s]
# train-00001-of-00002.parquet:   0%|          | 0.00/12.2M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/8.34M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/9.59M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4919 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1053 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1061 [00:00<?, ? examples/s]

# %%
from peft import LoraConfig
from datasets import load_dataset
from torch.utils.data import Dataset
from PIL import Image
from sklearn.metrics import accuracy_score, f1_score, recall_score
from torch.utils.data import Dataset
import random

class VQADataset(Dataset):
    def __init__(self, dataset, processor):
        self.dataset = dataset
        self.processor = processor

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        question = self.dataset[idx]['question']
        answer = self.dataset[idx]['answer']
        image = self.dataset[idx]['image']  # Assuming it's a PIL image

        return {
            "image": image,
            "query": {"en": question},
            "answers": [answer]
        }


# Define the MyDataCollator class
class MyDataCollator:
    def __init__(self, processor):
        self.processor = processor
        self.image_token = ''
        self.end_of_utterance_token = '<end_of_utterance>'
        self.pad_token_id = getattr(processor, 'pad_token_id', 0)  # Default to 0 if not found

    def __call__(self, examples):
        texts = []
        for example in examples:
            question = example["query"]['en']
            answer = random.choice(example["answers"])

            messages = [
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": "Answer briefly."},
                        {"type": "text", "text": self.image_token},
                        {"type": "text", "text": question}
                    ]
                },
                {
                    "role": "assistant",
                    "content": [
                        {"type": "text", "text": answer},
                        {"type": "text", "text": self.end_of_utterance_token}
                    ]
                }
            ]

            text = self.processor.apply_chat_template(messages, add_generation_prompt=False)

            if isinstance(text, list):
                text = " ".join(str(item) for item in text)
            else:
                text = str(text)

            texts.append(text.strip())

        text_batch = self.processor(text=texts, return_tensors="pt", padding=True)

        # Prepare the batch dictionary
        batch = {
            "input_ids": text_batch["input_ids"],
            "attention_mask": text_batch["attention_mask"]
        }

        # Create labels
        labels = batch["input_ids"].clone()
        labels[labels == self.pad_token_id] = -100  # Ignore padding in loss calculation
        batch["labels"] = labels

        return batch



test_dataset = VQADataset(dataset=dataset['test'], processor=processor)

data_collator = MyDataCollator(processor=processor)

# %%
release_memory(modelF)
# Out:
# [None]

# %%
import torch
import pandas as pd
from tqdm import tqdm
from accelerate.utils import release_memory

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
modelF.to(device)

predictions = []
ground_truths = []
queries = []
sampled_dataset = random.sample(list(test_dataset), 100)
# Generate text for each example
for example in tqdm(sampled_dataset, desc="Generating answers"):
    image = example["image"]
    query = example["query"]
    ground_truth = example["answers"]

    messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "Answer briefly."},
            {"type": "text", "text": processor.image_token},
            {"type": "text", "text": query.get('en', '')}
        ]
    }
]


    text = processor.apply_chat_template(messages, add_generation_prompt=True)

    inputs = processor(
        text=[text.strip()],
        images=[image],
        return_tensors="pt",
        padding=True
    )
    inputs = {k: v.to(device) for k, v in inputs.items()}


    # Generate predictions
    with torch.no_grad():
        generated_ids = modelF.generate(
                **inputs,
                max_new_tokens=3,  # Very short response
                do_sample=False,   # Deterministic outputs
                temperature=0.3,   # No randomness
                top_p=0.0,         # Focus on top token
                repetition_penalty=1.2  # Avoid repetitive outputs
            )

        release_memory(modelF)
        generated_text = processor.batch_decode(
            generated_ids[:, inputs["input_ids"].size(1):], skip_special_tokens=True
        )[0].strip()

    predictions.append(generated_text)
    ground_truths.append(ground_truth)
    queries.append(query)

# Create DataFrame
df = pd.DataFrame({
    "Query": queries,
    "Ground Truth": ground_truths,
    "Prediction": predictions
})
# Out:
# Generating answers:   0%|          | 0/100 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   1%|          | 1/100 [00:02<04:17,  2.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   2%|▏         | 2/100 [00:05<04:50,  2.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   3%|▎         | 3/100 [00:09<04:57,  3.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   4%|▍         | 4/100 [00:10<03:40,  2.29s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   5%|▌         | 5/100 [00:10<02:46,  1.76s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   6%|▌         | 6/100 [00:12<02:24,  1.53s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   7%|▋         | 7/100 [00:12<02:00,  1.30s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   8%|▊         | 8/100 [00:16<02:59,  1.95s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   9%|▉         | 9/100 [00:17<02:39,  1.76s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  10%|█         | 10/100 [00:20<02:59,  2.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  11%|█         | 11/100 [00:21<02:41,  1.81s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  12%|█▏        | 12/100 [00:24<03:17,  2.25s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  13%|█▎        | 13/100 [00:27<03:43,  2.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  14%|█▍        | 14/100 [00:29<03:06,  2.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  15%|█▌        | 15/100 [00:32<03:34,  2.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  16%|█▌        | 16/100 [00:35<03:51,  2.75s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  17%|█▋        | 17/100 [00:37<03:09,  2.28s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  18%|█▊        | 18/100 [00:40<03:35,  2.63s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  19%|█▉        | 19/100 [00:41<03:00,  2.23s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  20%|██        | 20/100 [00:42<02:32,  1.91s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  21%|██        | 21/100 [00:44<02:13,  1.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  22%|██▏       | 22/100 [00:44<01:51,  1.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  23%|██▎       | 23/100 [00:46<01:43,  1.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  24%|██▍       | 24/100 [00:47<01:37,  1.29s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  25%|██▌       | 25/100 [00:48<01:25,  1.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  26%|██▌       | 26/100 [00:49<01:24,  1.15s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  27%|██▋       | 27/100 [00:52<02:12,  1.82s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  28%|██▊       | 28/100 [00:55<02:34,  2.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  29%|██▉       | 29/100 [00:59<03:16,  2.76s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  30%|███       | 30/100 [01:00<02:39,  2.28s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  31%|███       | 31/100 [01:01<02:08,  1.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  32%|███▏      | 32/100 [01:02<01:51,  1.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  33%|███▎      | 33/100 [01:03<01:38,  1.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  34%|███▍      | 34/100 [01:07<02:12,  2.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  35%|███▌      | 35/100 [01:08<01:52,  1.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  36%|███▌      | 36/100 [01:09<01:39,  1.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  37%|███▋      | 37/100 [01:10<01:29,  1.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  38%|███▊      | 38/100 [01:13<02:00,  1.95s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  39%|███▉      | 39/100 [01:14<01:43,  1.70s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  40%|████      | 40/100 [01:18<02:11,  2.19s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  41%|████      | 41/100 [01:19<01:51,  1.89s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  42%|████▏     | 42/100 [01:20<01:36,  1.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  43%|████▎     | 43/100 [01:21<01:20,  1.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  44%|████▍     | 44/100 [01:22<01:14,  1.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  45%|████▌     | 45/100 [01:23<01:09,  1.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  46%|████▌     | 46/100 [01:26<01:40,  1.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  47%|████▋     | 47/100 [01:27<01:21,  1.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  48%|████▊     | 48/100 [01:28<01:07,  1.30s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  49%|████▉     | 49/100 [01:29<00:59,  1.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  50%|█████     | 50/100 [01:30<00:58,  1.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  51%|█████     | 51/100 [01:31<00:53,  1.09s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  52%|█████▏    | 52/100 [01:34<01:23,  1.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  53%|█████▎    | 53/100 [01:35<01:12,  1.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  54%|█████▍    | 54/100 [01:39<01:49,  2.38s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  55%|█████▌    | 55/100 [01:41<01:32,  2.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  56%|█████▌    | 56/100 [01:44<01:47,  2.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  57%|█████▋    | 57/100 [01:45<01:28,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  58%|█████▊    | 58/100 [01:46<01:14,  1.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  59%|█████▉    | 59/100 [01:50<01:30,  2.21s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  60%|██████    | 60/100 [01:53<01:41,  2.53s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  61%|██████    | 61/100 [01:54<01:23,  2.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  62%|██████▏   | 62/100 [01:55<01:09,  1.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  63%|██████▎   | 63/100 [01:56<01:00,  1.63s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  64%|██████▍   | 64/100 [01:57<00:52,  1.46s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  65%|██████▌   | 65/100 [01:59<00:47,  1.36s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  66%|██████▌   | 66/100 [02:00<00:43,  1.28s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  67%|██████▋   | 67/100 [02:00<00:37,  1.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  68%|██████▊   | 68/100 [02:02<00:36,  1.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  69%|██████▉   | 69/100 [02:05<00:55,  1.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  70%|███████   | 70/100 [02:06<00:45,  1.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  71%|███████   | 71/100 [02:09<00:59,  2.06s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  72%|███████▏  | 72/100 [02:10<00:47,  1.68s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  73%|███████▎  | 73/100 [02:11<00:40,  1.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  74%|███████▍  | 74/100 [02:14<00:53,  2.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  75%|███████▌  | 75/100 [02:15<00:44,  1.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  76%|███████▌  | 76/100 [02:19<00:54,  2.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  77%|███████▋  | 77/100 [02:22<00:59,  2.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  78%|███████▊  | 78/100 [02:23<00:46,  2.12s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  79%|███████▉  | 79/100 [02:24<00:38,  1.82s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  80%|████████  | 80/100 [02:28<00:45,  2.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  81%|████████  | 81/100 [02:31<00:49,  2.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  82%|████████▏ | 82/100 [02:32<00:38,  2.16s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  83%|████████▎ | 83/100 [02:35<00:42,  2.49s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  84%|████████▍ | 84/100 [02:37<00:33,  2.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  85%|████████▌ | 85/100 [02:38<00:26,  1.79s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  86%|████████▌ | 86/100 [02:39<00:22,  1.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  87%|████████▋ | 87/100 [02:42<00:27,  2.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  88%|████████▊ | 88/100 [02:43<00:21,  1.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  89%|████████▉ | 89/100 [02:44<00:16,  1.51s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  90%|█████████ | 90/100 [02:45<00:13,  1.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  91%|█████████ | 91/100 [02:46<00:10,  1.21s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  92%|█████████▏| 92/100 [02:47<00:09,  1.16s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  93%|█████████▎| 93/100 [02:48<00:08,  1.15s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  94%|█████████▍| 94/100 [02:49<00:06,  1.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  95%|█████████▌| 95/100 [02:50<00:05,  1.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  96%|█████████▌| 96/100 [02:51<00:04,  1.05s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  97%|█████████▋| 97/100 [02:54<00:05,  1.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  98%|█████████▊| 98/100 [02:56<00:03,  1.58s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  99%|█████████▉| 99/100 [02:56<00:01,  1.36s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers: 100%|██████████| 100/100 [03:00<00:00,  1.80s/it]

# %%
# !pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
import numpy as np
import torch
import pandas as pd
from tqdm import tqdm
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.meteor_score import meteor_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from fuzzywuzzy import fuzz
import nltk

nltk.download('wordnet')
nltk.download('omw-1.4')


binary_labels = [1 if "yes" in gt.lower() else 0 for gts in ground_truths for gt in gts]  # Convert to binary labels
binary_preds = [1 if "yes" in pred.lower() else 0 for pred in predictions]  # Convert predictions to binary

accuracy_binary = accuracy_score(binary_labels[:len(binary_preds)], binary_preds)

print(f"🌟 Binary Accuracy: {accuracy_binary:.4f}")
# Out:
# 🌟 Binary Accuracy: 0.6910
