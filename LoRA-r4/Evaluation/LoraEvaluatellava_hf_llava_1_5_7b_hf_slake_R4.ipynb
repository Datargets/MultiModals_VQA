# %%
# !pip install -U datasets
# !pip install fsspec==2023.9.2
# !pip install datasets
# !pip install peft
# !pip install -U bitsandbytes

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# Token is valid (permission: fineGrained).
# The token `1` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `1`

# %%
import torch
from transformers import AutoModel
from peft import PeftModel
import torch
from transformers import BitsAndBytesConfig
from transformers import AutoProcessor, BitsAndBytesConfig, AutoModelForImageTextToText,AutoModelForVision2Seq
from peft import LoraConfig
base_model_name = "llava-hf/llava-1.5-7b-hf"

adapters_name = "Dtarget/R4llava9JSlakF"

bnb_config = {
    "load_in_4bit": True,
    "bnb_4bit_quant_type": "nf4",
    "bnb_4bit_compute_dtype": torch.float16
}

# Load the base model with QLoRA for memory efficiency
modelF = AutoModelForVision2Seq.from_pretrained(
    base_model_name,
    torch_dtype=torch.float16,
    quantization_config=bnb_config  # QLoRA for memory efficiency
)


modelF = PeftModel.from_pretrained(modelF, adapters_name)
modelF = modelF.merge_and_unload()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/950 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.18G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/19.2M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:348: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(

# %%
processor = AutoProcessor.from_pretrained(
    "llava-hf/llava-1.5-7b-hf",
    do_image_splitting=False
)
# Out:
# processor_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/701 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/674 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/505 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/41.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]

# %%
from datasets import load_dataset

# %%
dataset = load_dataset("mdwiratathya/SLAKE-vqa-english")

# %%
from peft import LoraConfig
from datasets import load_dataset
from torch.utils.data import Dataset
from PIL import Image
from sklearn.metrics import accuracy_score, f1_score, recall_score
from torch.utils.data import Dataset
import random

class VQADataset(Dataset):
    def __init__(self, dataset, processor):
        self.dataset = dataset
        self.processor = processor

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        question = self.dataset[idx]['question']
        answer = self.dataset[idx]['answer']
        image = self.dataset[idx]['image']  # Assuming it's a PIL image

        return {
            "image": image,
            "query": {"en": question},
            "answers": [answer]
        }


# Define the MyDataCollator class
class MyDataCollator:
    def __init__(self, processor):
        self.processor = processor
        self.image_token = ''
        self.end_of_utterance_token = '<end_of_utterance>'
        self.pad_token_id = getattr(processor, 'pad_token_id', 0)  # Default to 0 if not found

    def __call__(self, examples):
        texts = []
        for example in examples:
            question = example["query"]['en']
            answer = random.choice(example["answers"])

            messages = [
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": "Answer briefly."},
                        {"type": "text", "text": self.image_token},
                        {"type": "text", "text": question}
                    ]
                },
                {
                    "role": "assistant",
                    "content": [
                        {"type": "text", "text": answer},
                        {"type": "text", "text": self.end_of_utterance_token}
                    ]
                }
            ]

            text = self.processor.apply_chat_template(messages, add_generation_prompt=False)

            if isinstance(text, list):
                text = " ".join(str(item) for item in text)
            else:
                text = str(text)

            texts.append(text.strip())

        text_batch = self.processor(text=texts, return_tensors="pt", padding=True)

        # Prepare the batch dictionary
        batch = {
            "input_ids": text_batch["input_ids"],
            "attention_mask": text_batch["attention_mask"]
        }

        # Create labels
        labels = batch["input_ids"].clone()
        labels[labels == self.pad_token_id] = -100  # Ignore padding in loss calculation
        batch["labels"] = labels

        return batch



test_dataset = VQADataset(dataset=dataset['test'], processor=processor)

data_collator = MyDataCollator(processor=processor)

# %%
release_memory(modelF)
# Out:
# [None]

# %%
import torch
import pandas as pd
from tqdm import tqdm
from accelerate.utils import release_memory

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
modelF.to(device)

predictions = []
ground_truths = []
queries = []
sampled_dataset = random.sample(list(test_dataset), 100)
# Generate text for each example
for example in tqdm(sampled_dataset, desc="Generating answers"):
    image = example["image"]
    query = example["query"]
    ground_truth = example["answers"]

    messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "Answer briefly."},
            {"type": "text", "text": processor.image_token},
            {"type": "text", "text": query.get('en', '')}
        ]
    }
]


    text = processor.apply_chat_template(messages, add_generation_prompt=True)

    inputs = processor(
        text=[text.strip()],
        images=[image],
        return_tensors="pt",
        padding=True
    )
    inputs = {k: v.to(device) for k, v in inputs.items()}


    # Generate predictions
    with torch.no_grad():
        generated_ids = modelF.generate(
                **inputs,
                max_new_tokens=32,  # Very short response
                do_sample=False,   # Deterministic outputs
                temperature=0.1,   # No randomness
                top_p=0.0,         # Focus on top token
                repetition_penalty=1.2  # Avoid repetitive outputs
            )

        release_memory(modelF)
        generated_text = processor.batch_decode(
            generated_ids[:, inputs["input_ids"].size(1):], skip_special_tokens=True
        )[0].strip()

    predictions.append(generated_text)
    ground_truths.append(ground_truth)
    queries.append(query)

# Create DataFrame
df = pd.DataFrame({
    "Query": queries,
    "Ground Truth": ground_truths,
    "Prediction": predictions
})
# Out:
# Generating answers:   0%|          | 0/100 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   1%|          | 1/100 [00:03<05:06,  3.10s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   2%|▏         | 2/100 [00:05<04:17,  2.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   3%|▎         | 3/100 [00:08<04:15,  2.63s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   4%|▍         | 4/100 [00:10<04:12,  2.63s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   5%|▌         | 5/100 [00:13<04:13,  2.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   6%|▌         | 6/100 [00:16<04:09,  2.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   7%|▋         | 7/100 [00:18<04:06,  2.65s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   8%|▊         | 8/100 [00:21<04:04,  2.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:   9%|▉         | 9/100 [00:24<04:06,  2.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  10%|█         | 10/100 [00:26<04:04,  2.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  11%|█         | 11/100 [00:29<03:59,  2.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  12%|█▏        | 12/100 [00:31<03:42,  2.53s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  13%|█▎        | 13/100 [00:34<03:51,  2.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  14%|█▍        | 14/100 [00:37<03:54,  2.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  15%|█▌        | 15/100 [00:40<03:51,  2.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  16%|█▌        | 16/100 [00:42<03:49,  2.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  17%|█▋        | 17/100 [00:45<03:46,  2.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  18%|█▊        | 18/100 [00:47<03:31,  2.58s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  19%|█▉        | 19/100 [00:50<03:20,  2.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  20%|██        | 20/100 [00:52<03:24,  2.56s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  21%|██        | 21/100 [00:55<03:18,  2.51s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  22%|██▏       | 22/100 [00:57<03:04,  2.37s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  23%|██▎       | 23/100 [00:58<02:38,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  24%|██▍       | 24/100 [01:01<02:57,  2.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  25%|██▌       | 25/100 [01:03<02:42,  2.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  26%|██▌       | 26/100 [01:05<02:41,  2.19s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  27%|██▋       | 27/100 [01:08<02:52,  2.36s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  28%|██▊       | 28/100 [01:11<03:03,  2.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  29%|██▉       | 29/100 [01:14<03:05,  2.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  30%|███       | 30/100 [01:16<03:06,  2.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  31%|███       | 31/100 [01:19<02:50,  2.48s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  32%|███▏      | 32/100 [01:21<02:49,  2.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  33%|███▎      | 33/100 [01:24<03:05,  2.76s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  34%|███▍      | 34/100 [01:27<02:54,  2.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  35%|███▌      | 35/100 [01:29<02:48,  2.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  36%|███▌      | 36/100 [01:32<02:48,  2.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  37%|███▋      | 37/100 [01:35<02:45,  2.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  38%|███▊      | 38/100 [01:38<02:48,  2.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  39%|███▉      | 39/100 [01:40<02:40,  2.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  40%|████      | 40/100 [01:42<02:25,  2.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  41%|████      | 41/100 [01:44<02:21,  2.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  42%|████▏     | 42/100 [01:46<02:12,  2.28s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  43%|████▎     | 43/100 [01:49<02:24,  2.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  44%|████▍     | 44/100 [01:52<02:16,  2.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  45%|████▌     | 45/100 [01:53<02:01,  2.21s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  46%|████▌     | 46/100 [01:56<02:04,  2.31s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  47%|████▋     | 47/100 [01:59<02:09,  2.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  48%|████▊     | 48/100 [02:01<02:09,  2.49s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  49%|████▉     | 49/100 [02:04<02:10,  2.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  50%|█████     | 50/100 [02:07<02:10,  2.61s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  51%|█████     | 51/100 [02:09<02:09,  2.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  52%|█████▏    | 52/100 [02:11<01:45,  2.21s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  53%|█████▎    | 53/100 [02:13<01:53,  2.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  54%|█████▍    | 54/100 [02:16<01:54,  2.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  55%|█████▌    | 55/100 [02:19<01:55,  2.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  56%|█████▌    | 56/100 [02:21<01:48,  2.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  57%|█████▋    | 57/100 [02:24<01:49,  2.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  58%|█████▊    | 58/100 [02:26<01:43,  2.46s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  59%|█████▉    | 59/100 [02:29<01:44,  2.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  60%|██████    | 60/100 [02:31<01:40,  2.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  61%|██████    | 61/100 [02:34<01:36,  2.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  62%|██████▏   | 62/100 [02:37<01:43,  2.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  63%|██████▎   | 63/100 [02:39<01:35,  2.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  64%|██████▍   | 64/100 [02:41<01:27,  2.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  65%|██████▌   | 65/100 [02:44<01:28,  2.53s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  66%|██████▌   | 66/100 [02:46<01:25,  2.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  67%|██████▋   | 67/100 [02:48<01:10,  2.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  68%|██████▊   | 68/100 [02:50<01:14,  2.31s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  69%|██████▉   | 69/100 [02:53<01:13,  2.36s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  70%|███████   | 70/100 [02:55<01:12,  2.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  71%|███████   | 71/100 [02:58<01:12,  2.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  72%|███████▏  | 72/100 [03:02<01:17,  2.75s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  73%|███████▎  | 73/100 [03:04<01:09,  2.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  74%|███████▍  | 74/100 [03:06<01:07,  2.61s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  75%|███████▌  | 75/100 [03:09<01:06,  2.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  76%|███████▌  | 76/100 [03:12<01:05,  2.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  77%|███████▋  | 77/100 [03:15<01:03,  2.75s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  78%|███████▊  | 78/100 [03:18<01:00,  2.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  79%|███████▉  | 79/100 [03:19<00:47,  2.28s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  80%|████████  | 80/100 [03:22<00:48,  2.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  81%|████████  | 81/100 [03:23<00:38,  2.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  82%|████████▏ | 82/100 [03:25<00:38,  2.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  83%|████████▎ | 83/100 [03:28<00:39,  2.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  84%|████████▍ | 84/100 [03:30<00:35,  2.21s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  85%|████████▌ | 85/100 [03:32<00:34,  2.30s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  86%|████████▌ | 86/100 [03:35<00:33,  2.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  87%|████████▋ | 87/100 [03:36<00:27,  2.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  88%|████████▊ | 88/100 [03:39<00:27,  2.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  89%|████████▉ | 89/100 [03:40<00:21,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  90%|█████████ | 90/100 [03:43<00:22,  2.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  91%|█████████ | 91/100 [03:46<00:21,  2.38s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  92%|█████████▏| 92/100 [03:49<00:20,  2.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  93%|█████████▎| 93/100 [03:51<00:16,  2.37s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  94%|█████████▍| 94/100 [03:53<00:13,  2.32s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  95%|█████████▌| 95/100 [03:55<00:11,  2.28s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  96%|█████████▌| 96/100 [03:57<00:08,  2.23s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  97%|█████████▋| 97/100 [03:59<00:06,  2.20s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  98%|█████████▊| 98/100 [04:03<00:05,  2.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers:  99%|█████████▉| 99/100 [04:05<00:02,  2.58s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating answers: 100%|██████████| 100/100 [04:06<00:00,  2.47s/it]

# %%
# !pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
import numpy as np
import torch
import pandas as pd
from tqdm import tqdm
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.meteor_score import meteor_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from fuzzywuzzy import fuzz
import nltk

# nltk.download('wordnet')
# nltk.download('omw-1.4')


binary_labels = [1 if "yes" in gt.lower() else 0 for gts in ground_truths for gt in gts]  # Convert to binary labels
binary_preds = [1 if "yes" in pred.lower() else 0 for pred in predictions]  # Convert predictions to binary

accuracy_binary = accuracy_score(binary_labels[:len(binary_preds)], binary_preds)

print(f"🌟 Binary Accuracy: {accuracy_binary:.4f}")
# Out:
# 🌟 Binary Accuracy: 0.8700
